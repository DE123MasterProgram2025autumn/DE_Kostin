# %% [markdown]
# #### 29.10.25, &copy; [Evhenii Kostin](https://github.com/DE123MasterProgram2025autumn/DE_Kostin), 2025

# %% [markdown]
# # Лабораторна робота №2: Інтеграція та об’єднання даних з різних джерел

# %% [markdown]
# __Мета:__ _освоїти повний цикл інтеграції реляційних даних у середовищі R: від завантаження даних з різноманітних джерел (CSV, Excel, Google Таблиці) до їх об’єднання за допомогою вертикальних (bind_rows) та горизонтальних (left_join, semi_join, anti_join) операцій. Навчитися будувати реалістичні ETL-конвеєри, які моделюють типові задачі інженера даних у production-середовищі._

# %% [markdown]
# ### Варіант 2
# #### Тема: Аналіз студентських оцінок за два семестри

# %%
# --- 0. ПІДКЛЮЧЕННЯ БІБЛІОТЕК ---
# Встановлюємо пакети, якщо їх немає
if (!require("tidyverse")) install.packages("tidyverse")
if (!require("writexl")) install.packages("writexl")

library(tidyverse) # Для tibble() та readr::write_csv()
library(writexl)   # Для запису .xlsx файлів

# --- 1. НАЛАШТУВАННЯ ТА СТВОРЕННЯ ПАПКИ ---
data_dir <- "data"
if (!dir.exists(data_dir)) {
  dir.create(data_dir, recursive = TRUE) # recursive = TRUE аналог os.makedirs
  message(paste("Створено папку:", data_dir))
} else {
  message(paste("Папка", data_dir, "вже існує."))
}

# --- 2. ГЕНЕРАЦІЯ ДАНИХ (у вигляді R tibbles) ---
# tibble - це сучасний аналог data.frame з tidyverse

# Довідник студентів
students <- tibble(
  student_id = c("S01", "S02", "S03", "S04", "S05", "S06"),
  full_name = c("Іваненко Петро", "Коваленко Марія", "Сидоренко Валерій", "Мельник Олена", "Кравчук Андрій", "Лисенко Ірина"),
  group = c("IT-21", "IT-21", "IT-22", "IT-22", "IT-21", "IT-22"),
  faculty = c("FICT", "FICT", "FICT", "FICT", "FICT", "FICT")
)

# --- Семестр 1 ---
grades_math_s1 <- tibble(student_id = c("S01", "S02", "S03", "S04"), exam_score = c(85, 92, 77, 60), project_score = c(90, 88, 80, 65))
grades_physics_s1 <- tibble(student_id = c("S01", "S02", "S03", "S04"), exam_score = c(95, 80, 82, 70), project_score = c(90, 85, 80, 75))
grades_cs_s1 <- tibble(student_id = c("S01", "S02", "S03", "S04"), exam_score = c(100, 90, 95, 80), project_score = c(95, 92, 90, 85))

# --- Семестр 2 ---
grades_math_s2 <- tibble(student_id = c("S01", "S02", "S05", "S06"), exam_score = c(88, 90, 75, 82), project_score = c(92, 85, 80, 80))
grades_physics_s2 <- tibble(student_id = c("S01", "S02", "S05", "S06"), exam_score = c(90, 82, 78, 88), project_score = c(95, 80, 82, 85))
grades_cs_s2 <- tibble(student_id = c("S01", "S02", "S05", "S06"), exam_score = c(98, 92, 80, 85), project_score = c(90, 90, 85, 88))

# --- Стипендії ---
scholarships <- tibble(
  student_id = c("S01", "S03", "S05"),
  scholarship_type = c("academic", "academic", "social"),
  amount = c(2000, 2000, 1500)
)

# --- 3. ЗАПИС ФАЙЛІВ ---

# Для запису кількох аркушів, writexl приймає іменований список (list)
semester1_data <- list(
  students = students,
  grades_math = grades_math_s1,
  grades_physics = grades_physics_s1,
  grades_cs = grades_cs_s1
)

semester2_data <- list(
  grades_math = grades_math_s2,
  grades_physics = grades_physics_s2,
  grades_cs = grades_cs_s2
)

# Використовуємо tryCatch для обробки помилок (аналог try...except)
tryCatch({
  # Запис Excel-файлів
  writexl::write_xlsx(semester1_data, path = "data/semester1.xlsx")
  writexl::write_xlsx(semester2_data, path = "data/semester2.xlsx")
  
  # Запис CSV-файлу (readr::write_csv не записує індекси за замовчуванням)
  readr::write_csv(scholarships, "data/scholarships.csv")
  
  message("\n--- R-скрипт успішно створив файли: ---")
  print(list.files(data_dir))
  
}, error = function(e) {
  message(paste("\n--- !!! Виникла помилка під час запису файлів:", e$message, "---"))
  message("Переконайтеся, що у вас встановлено 'writexl': install.packages('writexl')")
})
# Out:
# Loading required package: tidyverse
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: writexl
#
# Папка data вже існує.
#
#
# --- R-скрипт успішно створив файли: ---
#
# [1] "goals.csv"            "monthly_reports.xlsx" "scholarships.csv"
# [4] "semester1.xlsx"       "semester2.xlsx"       "traffic.json"
# [7] "website_data"

# %%
# Виконав(ла): Костін Євгеній | Група: КІ-24-1м | Викладач: Сидоренко В.М.

# --- 0. ЗАВАНТАЖЕННЯ БІБЛІОТЕК ---
# Встановлюємо пакети, якщо їх немає
if (!require("tidyverse")) install.packages("tidyverse")
if (!require("readxl")) install.packages("readxl")

library(tidyverse) # Для dplyr, readr, tidyr, purrr
library(readxl)    # Для читання Excel-файлів

# --- 1. ЗАВАНТАЖЕННЯ ДАНИХ ---

# 1.1. Завантажуємо довідник студентів (з S1) та стипендії
tryCatch({
  students_lookup <- readxl::read_excel("data/semester1.xlsx", sheet = "students")
  scholarships_lookup <- readr::read_csv("data/scholarships.csv")
  
  message("--- 1. Довідники завантажено ---")
  print(head(students_lookup))
  message("\n") # Для відступу
  print(head(scholarships_lookup))
  
}, error = function(e) {
  message("!!! ПОМИЛКА: Файли з даними не знайдено. Переконайтеся, що Скрипт №1 відпрацював.")
  # Зупиняємо виконання, якщо файлів немає
  stop(e)
})


# --- 2. ВЕРТИКАЛЬНЕ ОБ’ЄДНАННЯ (ETL для оцінок) ---

# 2.1. Функція для завантаження та обробки аркушів з оцінками
# (Аналог Python-функції `load_grades`)
load_grades <- function(filepath, semester_name) {
  # Завантажуємо аркуші
  grades_math <- read_excel(filepath, sheet = "grades_math") %>%
    mutate(subject = 'math')
    
  grades_physics <- read_excel(filepath, sheet = "grades_physics") %>%
    mutate(subject = 'physics')
    
  grades_cs <- read_excel(filepath, sheet = "grades_cs") %>%
    mutate(subject = 'cs')
    
  # Об'єднуємо їх вертикально (аналог pd.concat)
  semester_grades <- dplyr::bind_rows(grades_math, grades_physics, grades_cs) %>%
    mutate(semester = semester_name)
    
  return(semester_grades)
}

# 2.2. Створюємо grades_s1 та grades_s2
grades_s1 <- load_grades("data/semester1.xlsx", "S1")
grades_s2 <- load_grades("data/semester2.xlsx", "S2")

# 2.3. Об'єднуємо S1 і S2 у all_grades
all_grades <- dplyr::bind_rows(grades_s1, grades_s2)

message("\n\n--- 2. Вертикальне об'єднання (all_grades) ---")
print(head(all_grades)) # Перші рядки (S1)
message("\n")
print(tail(all_grades)) # Останні рядки (S2)


# --- 3. ГОРИЗОНТАЛЬНЕ ОБ’ЄДНАННЯ ---

# Створюємо єдиний аналітичний датафрейм (ADF)
# (Аналог pd.merge(how="left"))
# Додаємо інформацію про студентів (left join)
analytical_df <- dplyr::left_join(
  all_grades,
  students_lookup,
  by = "student_id" # `by` - аналог `on`
)

# Додаємо інформацію про стипендії (left join)
analytical_df <- dplyr::left_join(
  analytical_df,
  scholarships_lookup,
  by = "student_id"
)

message("\n\n--- 3. Горизонтальне об'єднання (analytical_df) ---")
# `amount` буде NA (Not Available) для тих, хто не має стипендії
print(analytical_df)


# --- 4. АГРЕГАЦІЯ ТА АНАЛІЗ ---

# 4.1. Розрахунок загального балу та допоміжних стовпців
# (Аналог df['new_col'] = ...)
analytical_df <- analytical_df %>%
  mutate(
    total_score = 0.6 * exam_score + 0.4 * project_score,
    
    # 4.2. Допоміжні стовпці
    is_high_achiever = total_score >= 90,
    has_scholarship = !is.na(scholarship_type) # !is.na() - аналог .notna()
  )

# 4.3. Групування та агрегація
# (Аналог .groupby().agg().reset_index())
analysis_by_group_semester <- analytical_df %>%
  group_by(group, semester) %>%
  summarise(
    # В R .sum() та .mean() автоматично перетворять TRUE/FALSE на 1/0
    mean_total_score = mean(total_score, na.rm = TRUE),
    high_achievers_count = sum(is_high_achiever, na.rm = TRUE),
    scholarship_share = mean(has_scholarship, na.rm = TRUE),
    .groups = 'drop' # .groups = 'drop' - аналог .reset_index()
  )

message("\n\n--- 4. Агрегація та Аналіз ---")
print(analysis_by_group_semester)


# --- 5. ФІЛЬТРУЮЧЕ З’ЄДНАННЯ (Емуляція semi_join та anti_join) ---

# 5.1. Визначення student_id, які отримували стипендію в обох семестрах
# Логіка: (Студенти S1 зі стипендією) semi_join (Студенти S2 зі стипендією)

# Студенти S1 зі стипендією (inner_join - аналог how='inner')
# pull() витягує стовпець як вектор (аналог .unique())
s1_schol_students <- dplyr::inner_join(
  grades_s1, scholarships_lookup, by = 'student_id'
) %>%
  pull(student_id) %>% # pull() - аналог [col_name]
  unique()

# Студенти S2 зі стипендією
s2_schol_students <- dplyr::inner_join(
  grades_s2, scholarships_lookup, by = 'student_id'
) %>%
  pull(student_id) %>%
  unique()

# Емуляція semi_join: %in% - це прямий аналог .isin()
students_in_both_mask <- s1_schol_students %in% s2_schol_students
students_in_both_ids <- s1_schol_students[students_in_both_mask]

students_in_both <- tibble(
  student_id = students_in_both_ids
)

message("\n\n--- 5.1. Студенти зі стипендією в обох семестрах (semi_join) ---")
# Повинен бути 'S01' (за нашими даними)
print(students_in_both)


# 5.2. Визначення студентів, які втратили стипендію після S1
# Логіка: (Студенти S1 зі стипендією) anti_join (Усі студенти S2)

# Усі унікальні студенти S2
s2_all_students_ids <- unique(grades_s2$student_id)

# Емуляція anti_join: ! - це аналог ~ (not)
lost_students_mask <- !(s1_schol_students %in% s2_all_students_ids)
lost_scholarship_students_ids <- s1_schol_students[lost_students_mask]

lost_scholarship_students <- tibble(
  student_id = lost_scholarship_students_ids
)

message("\n\n--- 5.2. Студенти, що втратили стипендію (S1+schol, anti_join S2) ---")
# Повинен бути 'S03' (за нашими даними)
print(lost_scholarship_students)
# Out:
# Loading required package: readxl
#
# Rows: 3 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): student_id, scholarship_type
# dbl (1): amount
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# --- 1. Довідники завантажено ---
#
# # A tibble: 6 × 4
#   student_id full_name         group faculty
#   <chr>      <chr>             <chr> <chr>
# 1 S01        Іваненко Петро    IT-21 FICT
# 2 S02        Коваленко Марія   IT-21 FICT
# 3 S03        Сидоренко Валерій IT-22 FICT
# 4 S04        Мельник Олена     IT-22 FICT
# 5 S05        Кравчук Андрій    IT-21 FICT
# 6 S06        Лисенко Ірина     IT-22 FICT
#
#
#
# # A tibble: 3 × 3
#   student_id scholarship_type amount
#   <chr>      <chr>             <dbl>
# 1 S01        academic           2000
# 2 S03        academic           2000
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6a083947-94ba-475d-8730-27cff0574f54' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
