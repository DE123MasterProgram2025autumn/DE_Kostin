# %% [markdown]
# #### 29.10.25, &copy; [Evhenii Kostin](https://github.com/DE123MasterProgram2025autumn/DE_Kostin), 2025

# %% [markdown]
# # Лабораторна робота №1. Основи маніпуляції даними з dplyr

# %% [markdown]
# __Мета:__ _освоїти фундаментальні операції маніпуляції даними в середовищі R за допомогою сучасного пакета dplyr, використовуючи функціональний підхід та конвеєрне програмування (%>% або |>). Навчитися ефективно фільтрувати, перетворювати, агрегувати та реструктурувати дані для подальшого аналізу чи завантаження в ETL-процеси._

# %% [markdown]
# ### Варіант 2
# Датасет _mtcars_
#
# #### 1. Вибірка та фільтрація
# Відфільтруйте автомобілі, у яких кількість циліндрів (cyl) дорівнює 6 або 8. Виберіть лише стовпці: mpg, hp, wt, cyl, gear. Відсортуйте за спаданням потужності (hp).
#
# #### 2. Створення нового стовпця
# Додайте стовпець power_to_weight (співвідношення потужності до ваги), розрахований за формулою: power_to_weight = hp / wt. Оберіть автомобілі, у яких power_to_weight > 50, і відсортуйте їх за спаданням power_to_weight.
#
# #### 3. Групування та агрегація
# Для кожної кількості передач (gear), яка представлена більш ніж у двох автомобілів, розрахуйте:
#
# середню витрату палива (mean_mpg), середню потужність (mean_hp), кількість автомобілів (n). Використайте summarise() та across() для агрегації числових стовпців (mpg, hp).
#
# #### 4. Перейменування та реструктуризація
# Візьміть результат попереднього пункту.
#
# Перейменуйте стовпець gear на Кількість_передач. Перемістіть стовпець n (кількість) на останнє місце. Перетворіть назви всіх інших стовпців на нижній регістр з підкресленням (наприклад, mean_mpg залишається, але якщо було б MeanMPG — перетворювалося б на mean_mpg).

# %%
# --- 0. ПІДКЛЮЧЕННЯ БІБЛІОТЕК ---
# Встановлюємо пакет, якщо його немає
if (!require("tidyverse")) install.packages("tidyverse")

library(tidyverse)

# --- Завантаження датасету ---
# 'mtcars' вже вбудований в R.
# Перетворимо назви рядків (моделі авто) на стовпець, щоб імітувати DataFrame
df <- mtcars %>%
  tibble::rownames_to_column(var = "model") %>%
  as_tibble() # Перетворюємо на зручний tibble

message("--- Початковий датафрейм (перші 5 рядків) ---")
print(head(df))


# --- 1. Вибірка та фільтрація ---
message("\n--- Завдання 1: 6/8 циліндрів, сортовано за hp ---")

# Використовуємо єдиний конвеєр (pipe) %>%
task1_result <- df %>%
  # Фільтруємо (cyl == 6 або 8)
  filter(cyl %in% c(6, 8)) %>%
  
  # Вибираємо стовпці
  select(model, mpg, hp, wt, cyl, gear) %>%
  
  # Сортуємо за спаданням 'hp'
  arrange(desc(hp))

print(head(task1_result))

# --- 2. Створення нового стовпця ---
message("\n--- Завдання 2: power_to_weight > 50 ---")

task2_result <- df %>%
  # Додаємо стовпець power_to_weight (аналог df.copy() + df['new_col'])
  mutate(power_to_weight = hp / wt) %>%
  
  # Фільтруємо > 50 та сортуємо
  filter(power_to_weight > 50) %>%
  arrange(desc(power_to_weight))

print(head(task2_result))

# --- 3. Групування та агрегація ---
message("\n--- Завдання 3: Групування за 'gear' > 2 ---")

task3_result <- df %>%
  # 1. Групуємо за 'gear'
  group_by(gear) %>%
  
  # 2. Фільтруємо групи, які мають > 2 автомобілів
  filter(n() > 2) %>%
  
  # 3. Агрегуємо (n() - аналог 'size')
  summarise(
    mean_mpg = mean(mpg, na.rm = TRUE), # Розраховуємо середнє для mpg
    mean_hp = mean(hp, na.rm = TRUE),   # Розраховуємо середнє для hp
    n = n()                             # Рахуємо кількість (n)
  ) %>%
  
  # 4. .groups = 'drop' (аналог .reset_index()) вже є в summarise
  ungroup() # Явно прибираємо групування

print(task3_result)

# --- 4. Перейменування та реструктуризація ---
message("\n--- Завдання 4: Фінальна таблиця ---")

task4_result <- task3_result %>%
  # Перейменовуємо 'gear' (аналог .rename(columns=...))
  rename(Кількість_передач = gear) %>%
  
  # Переміщуємо 'n' на останнє місце (аналог df[cols + ['n']])
  relocate(n, .after = last_col()) %>%
  
  # Перетворюємо назви стовпців на нижній регістр, крім вказаних
  # (Вони вже є, але це формальне виконання умови)
  rename_with(
    .fn = tolower,
    .cols = -c(Кількість_передач, n) # -c() означає "всі, крім цих"
  )

print(task4_result)
# Out:
# Loading required package: tidyverse
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# --- Початковий датафрейм (перші 5 рядків) ---
#
# # A tibble: 6 × 12
#   model          mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
#   <chr>        <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
# 1 Mazda RX4     21       6   160   110  3.9   2.62  16.5     0     1     4     4
# 2 Mazda RX4 W…  21       6   160   110  3.9   2.88  17.0     0     1     4     4
# 3 Datsun 710    22.8     4   108    93  3.85  2.32  18.6     1     1     4     1
# 4 Hornet 4 Dr…  21.4     6   258   110  3.08  3.22  19.4     1     0     3     1
# 5 Hornet Spor…  18.7     8   360   175  3.15  3.44  17.0     0     0     3     2
# 6 Valiant       18.1     6   225   105  2.76  3.46  20.2     1     0     3     1
#
# --- Завдання 1: 6/8 циліндрів, сортовано за hp ---
#
# # A tibble: 6 × 6
#   model                 mpg    hp    wt   cyl  gear
#   <chr>               <dbl> <dbl> <dbl> <dbl> <dbl>
# 1 Maserati Bora        15     335  3.57     8     5
# 2 Ford Pantera L       15.8   264  3.17     8     5
# 3 Duster 360           14.3   245  3.57     8     3
# 4 Camaro Z28           13.3   245  3.84     8     3
# 5 Chrysler Imperial    14.7   230  5.34     8     3
# 6 Lincoln Continental  10.4   215  5.42     8     3
#
# --- Завдання 2: power_to_weight > 50 ---
#
# # A tibble: 6 × 13
#   model          mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
#   <chr>        <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
# 1 Maserati Bo…  15       8 301     335  3.54  3.57  14.6     0     1     5     8
# 2 Ford Panter…  15.8     8 351     264  4.22  3.17  14.5     0     1     5     4
# 3 Lotus Europa  30.4     4  95.1   113  3.77  1.51  16.9     1     1     5     2
# 4 Duster 360    14.3     8 360     245  3.21  3.57  15.8     0     0     3     4
# 5 Camaro Z28    13.3     8 350     245  3.73  3.84  15.4     0     0     3     4
# 6 Ferrari Dino  19.7     6 145     175  3.62  2.77  15.5     0     1     5     6
# # ℹ 1 more variable: power_to_weight <dbl>
#
# --- Завдання 3: Групування за 'gear' > 2 ---
#
# # A tibble: 3 × 4
#    gear mean_mpg mean_hp     n
#   <dbl>    <dbl>   <dbl> <int>
# 1     3     16.1   176.     15
# 2     4     24.5    89.5    12
# 3     5     21.4   196.      5
#
# --- Завдання 4: Фінальна таблиця ---
#
# # A tibble: 3 × 4
#   Кількість_передач mean_mpg mean_hp     n
#               <dbl>    <dbl>   <dbl> <int>
# 1                 3     16.1   176.     15
# 2                 4     24.5    89.5    12
# 3                 5     21.4   196.      5

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6a083947-94ba-475d-8730-27cff0574f54' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
