# %% [markdown]
# #### 29.10.25, &copy; [Evhenii Kostin](https://github.com/DE123MasterProgram2025autumn/DE_Kostin), 2025

# %% [markdown]
# # Лабораторна робота №3:Робота зі структурованими даними, перетворення форматів та віконні операції

# %% [markdown]
# __Мета:__ _освоїти сучасні методи обробки неструктурованих та напівструктурованих даних (JSON), навчитися перетворювати формати таблиць (широкий ↔︎ довгий) за допомогою tidyr, а також застосовувати віконні функції для аналізу даних у контексті груп (наприклад, часових рядів, відділів, регіонів). Ці навички є ключовими для підготовки даних у складних ETL-процесах._

# %% [markdown]
# ### Варіант 2
# #### Тема: Аналіз даних про веб-трафік та маркетингові кампанії

# %%
# Виконав(ла): Костін Євгеній | Група: КІ-24-1м | Викладач: Сидоренко В.М.
# Лабораторна робота №3: Єдиний скрипт (Генерація + Рішення) - R-версія

# --- 0. ПІДКЛЮЧЕННЯ БІБЛІОТЕК ---
# Встановлюємо пакети, якщо їх немає
if (!require("tidyverse")) install.packages("tidyverse")
if (!require("jsonlite")) install.packages("jsonlite")
if (!require("readxl")) install.packages("readxl")
if (!require("writexl")) install.packages("writexl")

library(tidyverse)
library(jsonlite)
library(readxl)
library(writexl)

# --- ЕТАП 0: ГЕНЕРАЦІЯ ДАНИХ (Setup) ---
message("--- ЕТАП 0: СТВОРЕННЯ ВИХІДНИХ ФАЙЛІВ ---")

# --- 1. НАЛАШТУВАННЯ ТА СТВОРЕННЯ ПАПКИ ---
data_dir <- "data"
if (!dir.exists(data_dir)) {
  dir.create(data_dir)
  message(paste("Створено папку:", data_dir))
} else {
  message(paste("Папка", data_dir, "вже існує."))
}

# --- 2. ГЕНЕРАЦІЯ ДАНИХ ---

# 2.1. traffic.json
# (Використовуємо R-списки, які є аналогами Python-словників)
traffic_data <- list(
  list(
    date = "2024-01-05", page_views = 1250, unique_users = 840, bounce_rate = 0.42,
    campaigns = list(
      list(name = "google_ads", channel = "paid_search", cost = 120),
      list(name = "email_jan", channel = "email", cost = 50)
    )
  ),
  list(
    date = "2024-01-15", page_views = 1300, unique_users = 900, bounce_rate = 0.40,
    campaigns = list(
      list(name = "google_ads", channel = "paid_search", cost = 130),
      list(name = "facebook_jan", channel = "social", cost = 0) # Вартість 0
    )
  ),
  list(
    date = "2024-02-05", page_views = 1100, unique_users = 750, bounce_rate = 0.45, # Bounce rate зріс
    campaigns = list(
      list(name = "google_ads", channel = "paid_search", cost = 110),
      list(name = "email_feb", channel = "email", cost = 40)
    )
  ),
  list(
    date = "2024-02-15", page_views = 1150, unique_users = 780, bounce_rate = 0.44,
    campaigns = list(
      list(name = "google_ads", channel = "paid_search", cost = 115)
    )
  ),
  list(
    date = "2024-03-05", page_views = 1400, unique_users = 950, bounce_rate = 0.38, # Bounce rate впав
    campaigns = list(
      list(name = "google_ads", channel = "paid_search", cost = 140),
      list(name = "email_mar", channel = "email", cost = 55)
    )
  )
)

# Запис JSON-файлу
json_path <- file.path(data_dir, "traffic.json")
# auto_unbox = TRUE робить [120] -> 120, pretty = TRUE додає відступи
jsonlite::write_json(traffic_data, json_path, auto_unbox = TRUE, pretty = TRUE)
message("Файл 'traffic.json' створено.")

# 2.2. monthly_reports.xlsx
df_jan <- tibble(page = c('/home', '/products', '/contact'), sessions = c(15000, 8000, 1500), avg_duration_sec = c(120, 180, 90))
df_feb <- tibble(page = c('/home', '/products', '/contact', '/blog'), sessions = c(13000, 7500, 1400, 1000), avg_duration_sec = c(110, 175, 95, 200))
df_mar <- tibble(page = c('/home', '/products', '/contact', '/blog'), sessions = c(16000, 8500, 1600, 1200), avg_duration_sec = c(125, 185, 90, 210))

excel_path <- file.path(data_dir, "monthly_reports.xlsx")
# writexl::write_xlsx елегантно приймає іменований список
tryCatch({
  writexl::write_xlsx(
    list(jan = df_jan, feb = df_feb, mar = df_mar),
    path = excel_path
  )
  message("Файл 'monthly_reports.xlsx' створено.")
}, error = function(e) {
  message(paste("Помилка запису Excel:", e$message))
})

# 2.3. goals.csv
goals_df <- tibble(metric = c('total_users', 'total_sessions'), target_value = c(2500, 50000))
csv_path <- file.path(data_dir, "goals.csv")
readr::write_csv(goals_df, csv_path)
message("Файл 'goals.csv' створено.")
message("--- ЕТАП 0 ЗАВЕРШЕНО. ПОЧАТОК АНАЛІЗУ (ЕТАПИ 1-4) ---\n")


# --- ЕТАП 1: РОБОТА З JSON ---
message("--- ЕТАП 1: РОБОТА З JSON ---")

# 1.1. & 1.2. Завантажуємо та "розгортаємо" JSON
# (Аналог pd.json_normalize з `record_path` та `meta`)
# simplifyVector = TRUE автоматично перетворює JSON на data.frame,
# а tidyr::unnest() "розгортає" вкладений список `campaigns` у нові рядки.
daily_campaign_metrics <- jsonlite::read_json(json_path, simplifyVector = TRUE) %>%
  as_tibble() %>%
  tidyr::unnest(campaigns)

# 1.3. Залишаємо лише записи, де вартість кампанії > 0
daily_campaign_metrics <- daily_campaign_metrics %>%
  filter(cost > 0)

message("Результат Етапу 1 (daily_campaign_metrics):")
print(daily_campaign_metrics)


# --- ЕТАП 2: ПЕРЕТВОРЕННЯ ФОРМАТІВ ---
message("\n--- ЕТАП 2: ПЕРЕТВОРЕННЯ ФОРМАТІВ ---")

# 2.1. & 2.2. Завантажуємо всі аркуші з Excel і об'єднуємо
# (Аналог pd.read_excel(sheet_name=None) та pd.concat)
sheet_names <- readxl::excel_sheets(excel_path)

monthly_traffic <- purrr::map_df(sheet_names, ~{
  readxl::read_excel(excel_path, sheet = .x) %>%
    mutate(month_name = .x) # Додаємо стовпець з назвою аркуша
})

message("Результат 2.2 (monthly_traffic):")
print(head(monthly_traffic))

# 2.3. Завантажуємо goals.csv
goals <- readr::read_csv(csv_path)
message("\nРезультат 2.3 (goals):")
print(goals)


# --- ЕТАП 3: ОБ’ЄДНАННЯ ТА ВІКОННІ ОПЕРАЦІЇ ---
message("\n--- ЕТАП 3: ВІКОННІ ОПЕРАЦІЇ ---")

# 3.1. Перетворюємо 'date' у 'month' для агрегації
# 3.2. Агрегуємо дані до рівня місяця
# (Аналог groupby().agg())
monthly_summary <- daily_campaign_metrics %>%
  mutate(month = format(as.Date(date), "%Y-%m")) %>%
  group_by(month) %>%
  summarise(
    page_views = mean(page_views, na.rm = TRUE),
    unique_users = mean(unique_users, na.rm = TRUE),
    bounce_rate = mean(bounce_rate, na.rm = TRUE),
    total_cost = sum(cost, na.rm = TRUE),
    .groups = 'drop' # Завершити групування
  ) %>%
  # 3.3. Розрахунок конверсії
  mutate(conversion = unique_users / page_views) %>%
  # 3.4. Розрахунок ROI
  mutate(ROI = (unique_users * 0.1 - total_cost) / total_cost)

# --- 3.5. Віконні функції ---
# (Аналог .rank(), .diff(), .cumsum())
monthly_summary <- monthly_summary %>%
  arrange(month) %>% # Важливо сортувати перед diff() та cumsum()
  mutate(
    # Ранжування: ROI (min_rank - аналог method='min')
    roi_rank = min_rank(desc(ROI)),
    
    # Зсув: зміна bounce rate (lag() - аналог .diff())
    bounce_change = bounce_rate - lag(bounce_rate),
    
    # Накопичення: унікальні користувачі
    cum_users = cumsum(unique_users)
  )

message("Результат Етапу 3 (monthly_summary з віконними функціями):")
print(monthly_summary)


# --- ЕТАП 4: АНАЛІЗ ---
message("\n--- ЕТАП 4: АНАЛІЗ ---")

# 4.1. Перевірка досягнення цілей
target_users_value <- goals %>%
  filter(metric == 'total_users') %>%
  pull(target_value) # pull() витягує значення стовпця

final_cum_users <- monthly_summary %>%
  pull(cum_users) %>%
  last() # Останнє значення

message(sprintf("Ціль по 'total_users': %s", target_users_value))
message(sprintf("Накопичено користувачів (сума середньоденних): %.2f", final_cum_users))

if (final_cum_users >= target_users_value) {
  message(">>> Ціль досягнуто!")
} else {
  message(">>> Ціль не досягнуто.")
}

# 4.2. Аналог "semi_join": місяці, коли *всі* кампанії мали ROI > 0
message("\n4.2. Аналіз 'Semi-Join' (місяці, де ROI > 0 для *всіх* кампаній):")

# Розраховуємо ROI для *кожної окремої* кампанії (з Етапу 1)
daily_campaign_metrics_with_roi <- daily_campaign_metrics %>%
  mutate(
    month = format(as.Date(date), "%Y-%m"),
    ROI = (unique_users * 0.1 - cost) / cost
  )

# .filter() в R (з dplyr) може працювати з групами
# (Аналог pandas .groupby().filter(lambda...))
good_months_df <- daily_campaign_metrics_with_roi %>%
  group_by(month) %>%
  filter(all(ROI > 0)) %>% # Залишити групи, де ВСІ ROI > 0
  ungroup()

if (nrow(good_months_df) == 0) {
  message("Не знайдено місяців, де *всі* кампанії мали ROI > 0.")
} else {
  message("Місяці, де всі кампанії мали ROI > 0:")
  print(unique(good_months_df$month))
}

# 4.3. Аналог "anti_join": місяці, коли були витрати, але bounce rate зріс
message("\n4.3. Аналіз 'Anti-Join' (витрати були, bounce rate зріс):")
# Використовуємо 'monthly_summary' з Етапу 3
bad_months_df <- monthly_summary %>%
  filter(total_cost > 0 & bounce_change > 0)

if (nrow(bad_months_df) == 0) {
  message("Не знайдено місяців, де одночасно були витрати і зріс bounce rate.")
} else {
  message("Місяці з витратами та зростанням bounce rate:")
  print(bad_months_df %>% select(month, total_cost, bounce_change))
}

message("\n--- АНАЛІЗ ЗАВЕРШЕНО ---")
# Out:
# Loading required package: tidyverse
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: jsonlite
#
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
#
# Loading required package: readxl
#
# Loading required package: writexl
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘writexl’”
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6a083947-94ba-475d-8730-27cff0574f54' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
